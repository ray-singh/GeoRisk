# %%
import sdmx 
import pandas as pd
# Out:
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.

# %%
# Establishing connection to IMF
IMF_DATA = sdmx.Client('IMF_DATA')

# Code for accessing Govt. Debt dataset
key = '.GGXWDG_NGDP.A'

# Importing dataset as a dataframe
dataset = pd.read_csv('dataset.csv')

# %%
govt_debt = []

for id in dataset['id']:
    temp_key = id + key
    try:
        data_msg = IMF_DATA.data('WEO',  key=temp_key, params={'startPeriod': 2023, 'endPeriod':2025})
        gdp_df = sdmx.to_pandas(data_msg)
        govt_debt.append(gdp_df[-1])
    except:
        govt_debt.append(-99999.0)
# Out:
# xml.Reader got no structure=… argument for StructureSpecificData
# xml.Reader got no structure=… argument for StructureSpecificData
# xml.Reader got no structure=… argument for StructureSpecificData
# xml.Reader got no structure=… argument for StructureSpecificData
# xml.Reader got no structure=… argument for StructureSpecificData
# xml.Reader got no structure=… argument for StructureSpecificData
# xml.Reader got no structure=… argument for StructureSpecificData
# xml.Reader got no structure=… argument for StructureSpecificData
# xml.Reader got no structure=… argument for StructureSpecificData
# xml.Reader got no structure=… argument for StructureSpecificData
# xml.Reader got no structure=… argument for StructureSpecificData
# xml.Reader got no structure=… argument for StructureSpecificData
# xml.Reader got no structure=… argument for StructureSpecificData
# xml.Reader got no structure=… argument for StructureSpecificData
# xml.Reader got no structure=… argument for StructureSpecificData
# xml.Reader got no structure=… argument for StructureSpecificData
# xml.Reader got no structure=… argument for StructureSpecificData
# xml.Reader got no structure=… argument for StructureSpecificData
# xml.Reader got no structure=… argument for StructureSpecificData
# xml.Reader got no structure=… argument for StructureSpecificData
# xml.Reader got no structure=… argument for StructureSpecificData
# xml.Reader got no structure=… argument for StructureSpecificData
# xml.Reader got no structure=… argument for StructureSpecificData
# xml.Reader got no structure=… argument for StructureSpecificData
# xml.Reader got no structure=… argument for StructureSpecificData
# xml.Reader got no structure=… argument for StructureSpecificData
# xml.Reader got no structure=… argument for StructureSpecificData
# xml.Reader got no structure=… argument for StructureSpecificData
# xml.Reader got no structure=… argument for StructureSpecificData
# xml.Reader got no structure=… argument for StructureSpecificData
# xml.Reader got no structure=… argument for StructureSpecificData
# xml.Reader got no structure=… argument for StructureSpecificData
# xml.Reader got no structure=… argument for StructureSpecificData
# xml.Reader got no structure=… argument for StructureSpecificData
# xml.Reader got no structure=… argument for StructureSpecificData
# xml.Reader got no structure=… argument for StructureSpecificData
# xml.Reader got no structure=… argument for StructureSpecificData
# xml.Reader got no structure=… argument for StructureSpecificData
# xml.Reader got no structure=… argument for StructureSpecificData
# xml.Reader got no structure=… argument for StructureSpecificData
# xml.Reader got no structure=… argument for StructureSpecificData
# xml.Reader got no structure=… argument for StructureSpecificData
# xml.Reader got no structure=… argument for StructureSpecificData
# xml.Reader got no structure=… argument for StructureSpecificData
# xml.Reader got no structure=… argument for StructureSpecificData
# xml.Reader got no structure=… argument for StructureSpecificData
# xml.Reader got no structure=… argument for StructureSpecificData
# xml.Reader got no structure=… argument for StructureSpecificData
# xml.Reader got no structure=… argument for StructureSpecificData
# xml.Reader got no structure=… argument for StructureSpecificData
# xml.Reader got no structure=… argument for StructureSpecificData
# xml.Reader got no structure=… argument for StructureSpecificData
# xml.Reader got no structure=… argument for StructureSpecificData
# xml.Reader got no structure=… argument for StructureSpecificData
# xml.Reader got no structure=… argument for StructureSpecificData
# xml.Reader got no structure=… argument for StructureSpecificData
# xml.Reader got no structure=… argument for StructureSpecificData
# xml.Reader got no structure=… argument for StructureSpecificData
# xml.Reader got no structure=… argument for StructureSpecificData
# xml.Reader got no structure=… argument for StructureSpecificData
# xml.Reader got no structure=… argument for StructureSpecificData
# xml.Reader got no structure=… argument for StructureSpecificData
# xml.Reader got no structure=… argument for StructureSpecificData
# xml.Reader got no structure=… argument for StructureSpecificData
# xml.Reader got no structure=… argument for StructureSpecificData
# xml.Reader got no structure=… argument for StructureSpecificData
# xml.Reader got no structure=… argument for StructureSpecificData
# xml.Reader got no structure=… argument for StructureSpecificData
# xml.Reader got no structure=… argument for StructureSpecificData
# xml.Reader got no structure=… argument for StructureSpecificData
# xml.Reader got no structure=… argument for StructureSpecificData
# xml.Reader got no structure=… argument for StructureSpecificData
# xml.Reader got no structure=… argument for StructureSpecificData
# xml.Reader got no structure=… argument for StructureSpecificData
# xml.Reader got no structure=… argument for StructureSpecificData
# xml.Reader got no structure=… argument for StructureSpecificData
# xml.Reader got no structure=… argument for StructureSpecificData
# xml.Reader got no structure=… argument for StructureSpecificData
# xml.Reader got no structure=… argument for StructureSpecificData
# xml.Reader got no structure=… argument for StructureSpecificData
# xml.Reader got no structure=… argument for StructureSpecificData
# xml.Reader got no structure=… argument for StructureSpecificData
# xml.Reader got no structure=… argument for StructureSpecificData
# xml.Reader got no structure=… argument for StructureSpecificData
# xml.Reader got no structure=… argument for StructureSpecificData
# xml.Reader got no structure=… argument for StructureSpecificData
# xml.Reader got no structure=… argument for StructureSpecificData
# xml.Reader got no structure=… argument for StructureSpecificData
# xml.Reader got no structure=… argument for StructureSpecificData
# xml.Reader got no structure=… argument for StructureSpecificData
# xml.Reader got no structure=… argument for StructureSpecificData
# xml.Reader got no structure=… argument for StructureSpecificData
# xml.Reader got no structure=… argument for StructureSpecificData
# xml.Reader got no structure=… argument for StructureSpecificData
# xml.Reader got no structure=… argument for StructureSpecificData
# xml.Reader got no structure=… argument for StructureSpecificData
# xml.Reader got no structure=… argument for StructureSpecificData
# xml.Reader got no structure=… argument for StructureSpecificData
# xml.Reader got no structure=… argument for StructureSpecificData
# xml.Reader got no structure=… argument for StructureSpecificData
# xml.Reader got no structure=… argument for StructureSpecificData
# xml.Reader got no structure=… argument for StructureSpecificData
# xml.Reader got no structure=… argument for StructureSpecificData
# xml.Reader got no structure=… argument for StructureSpecificData
# xml.Reader got no structure=… argument for StructureSpecificData
# xml.Reader got no structure=… argument for StructureSpecificData
# xml.Reader got no structure=… argument for StructureSpecificData
# xml.Reader got no structure=… argument for StructureSpecificData
# xml.Reader got no structure=… argument for StructureSpecificData
# xml.Reader got no structure=… argument for StructureSpecificData
# xml.Reader got no structure=… argument for StructureSpecificData
# xml.Reader got no structure=… argument for StructureSpecificData
# xml.Reader got no structure=… argument for StructureSpecificData
# xml.Reader got no structure=… argument for StructureSpecificData
# xml.Reader got no structure=… argument for StructureSpecificData
# xml.Reader got no structure=… argument for StructureSpecificData
# xml.Reader got no structure=… argument for StructureSpecificData
# xml.Reader got no structure=… argument for StructureSpecificData
# xml.Reader got no structure=… argument for StructureSpecificData
# xml.Reader got no structure=… argument for StructureSpecificData
# xml.Reader got no structure=… argument for StructureSpecificData
# xml.Reader got no structure=… argument for StructureSpecificData
# xml.Reader got no structure=… argument for StructureSpecificData
# xml.Reader got no structure=… argument for StructureSpecificData
# xml.Reader got no structure=… argument for StructureSpecificData
# xml.Reader got no structure=… argument for StructureSpecificData
# xml.Reader got no structure=… argument for StructureSpecificData
# xml.Reader got no structure=… argument for StructureSpecificData
# xml.Reader got no structure=… argument for StructureSpecificData
# xml.Reader got no structure=… argument for StructureSpecificData
# xml.Reader got no structure=… argument for StructureSpecificData
# xml.Reader got no structure=… argument for StructureSpecificData
# xml.Reader got no structure=… argument for StructureSpecificData
# xml.Reader got no structure=… argument for StructureSpecificData
# xml.Reader got no structure=… argument for StructureSpecificData
# xml.Reader got no structure=… argument for StructureSpecificData
# xml.Reader got no structure=… argument for StructureSpecificData
# xml.Reader got no structure=… argument for StructureSpecificData
# xml.Reader got no structure=… argument for StructureSpecificData
# xml.Reader got no structure=… argument for StructureSpecificData
# xml.Reader got no structure=… argument for StructureSpecificData
# xml.Reader got no structure=… argument for StructureSpecificData
# xml.Reader got no structure=… argument for StructureSpecificData
# xml.Reader got no structure=… argument for StructureSpecificData
# xml.Reader got no structure=… argument for StructureSpecificData
# xml.Reader got no structure=… argument for StructureSpecificData
# xml.Reader got no structure=… argument for StructureSpecificData
# xml.Reader got no structure=… argument for StructureSpecificData
# xml.Reader got no structure=… argument for StructureSpecificData
# xml.Reader got no structure=… argument for StructureSpecificData
# xml.Reader got no structure=… argument for StructureSpecificData
# xml.Reader got no structure=… argument for StructureSpecificData
# xml.Reader got no structure=… argument for StructureSpecificData
# xml.Reader got no structure=… argument for StructureSpecificData
# xml.Reader got no structure=… argument for StructureSpecificData
# xml.Reader got no structure=… argument for StructureSpecificData
# xml.Reader got no structure=… argument for StructureSpecificData
# xml.Reader got no structure=… argument for StructureSpecificData
# xml.Reader got no structure=… argument for StructureSpecificData
# xml.Reader got no structure=… argument for StructureSpecificData
# xml.Reader got no structure=… argument for StructureSpecificData
# xml.Reader got no structure=… argument for StructureSpecificData
# xml.Reader got no structure=… argument for StructureSpecificData
# xml.Reader got no structure=… argument for StructureSpecificData
# xml.Reader got no structure=… argument for StructureSpecificData
# xml.Reader got no structure=… argument for StructureSpecificData
# xml.Reader got no structure=… argument for StructureSpecificData
# xml.Reader got no structure=… argument for StructureSpecificData
# xml.Reader got no structure=… argument for StructureSpecificData
# xml.Reader got no structure=… argument for StructureSpecificData
# xml.Reader got no structure=… argument for StructureSpecificData
# xml.Reader got no structure=… argument for StructureSpecificData
# xml.Reader got no structure=… argument for StructureSpecificData
# xml.Reader got no structure=… argument for StructureSpecificData
# xml.Reader got no structure=… argument for StructureSpecificData
# xml.Reader got no structure=… argument for StructureSpecificData
# xml.Reader got no structure=… argument for StructureSpecificData
# xml.Reader got no structure=… argument for StructureSpecificData
# xml.Reader got no structure=… argument for StructureSpecificData
# xml.Reader got no structure=… argument for StructureSpecificData
# xml.Reader got no structure=… argument for StructureSpecificData
# xml.Reader got no structure=… argument for StructureSpecificData
# xml.Reader got no structure=… argument for StructureSpecificData
# xml.Reader got no structure=… argument for StructureSpecificData
# xml.Reader got no structure=… argument for StructureSpecificData
# xml.Reader got no structure=… argument for StructureSpecificData
# xml.Reader got no structure=… argument for StructureSpecificData
# xml.Reader got no structure=… argument for StructureSpecificData
# xml.Reader got no structure=… argument for StructureSpecificData
# xml.Reader got no structure=… argument for StructureSpecificData
# xml.Reader got no structure=… argument for StructureSpecificData
# xml.Reader got no structure=… argument for StructureSpecificData
# xml.Reader got no structure=… argument for StructureSpecificData
# xml.Reader got no structure=… argument for StructureSpecificData
# xml.Reader got no structure=… argument for StructureSpecificData
# xml.Reader got no structure=… argument for StructureSpecificData
# xml.Reader got no structure=… argument for StructureSpecificData
# xml.Reader got no structure=… argument for StructureSpecificData
# xml.Reader got no structure=… argument for StructureSpecificData
# xml.Reader got no structure=… argument for StructureSpecificData
# xml.Reader got no structure=… argument for StructureSpecificData
# xml.Reader got no structure=… argument for StructureSpecificData
# xml.Reader got no structure=… argument for StructureSpecificData
# xml.Reader got no structure=… argument for StructureSpecificData
# xml.Reader got no structure=… argument for StructureSpecificData
# xml.Reader got no structure=… argument for StructureSpecificData
# xml.Reader got no structure=… argument for StructureSpecificData
# xml.Reader got no structure=… argument for StructureSpecificData
# xml.Reader got no structure=… argument for StructureSpecificData
# xml.Reader got no structure=… argument for StructureSpecificData
# xml.Reader got no structure=… argument for StructureSpecificData
# xml.Reader got no structure=… argument for StructureSpecificData
# xml.Reader got no structure=… argument for StructureSpecificData
# xml.Reader got no structure=… argument for StructureSpecificData
# xml.Reader got no structure=… argument for StructureSpecificData
# xml.Reader got no structure=… argument for StructureSpecificData
# xml.Reader got no structure=… argument for StructureSpecificData
# xml.Reader got no structure=… argument for StructureSpecificData
# xml.Reader got no structure=… argument for StructureSpecificData
# xml.Reader got no structure=… argument for StructureSpecificData
# xml.Reader got no structure=… argument for StructureSpecificData
# xml.Reader got no structure=… argument for StructureSpecificData
# xml.Reader got no structure=… argument for StructureSpecificData
# xml.Reader got no structure=… argument for StructureSpecificData
# xml.Reader got no structure=… argument for StructureSpecificData
# xml.Reader got no structure=… argument for StructureSpecificData
# xml.Reader got no structure=… argument for StructureSpecificData
# xml.Reader got no structure=… argument for StructureSpecificData
# xml.Reader got no structure=… argument for StructureSpecificData
# xml.Reader got no structure=… argument for StructureSpecificData
# xml.Reader got no structure=… argument for StructureSpecificData
# xml.Reader got no structure=… argument for StructureSpecificData
# xml.Reader got no structure=… argument for StructureSpecificData
# xml.Reader got no structure=… argument for StructureSpecificData
# xml.Reader got no structure=… argument for StructureSpecificData
# xml.Reader got no structure=… argument for StructureSpecificData
# xml.Reader got no structure=… argument for StructureSpecificData
# xml.Reader got no structure=… argument for StructureSpecificData
# xml.Reader got no structure=… argument for StructureSpecificData
# xml.Reader got no structure=… argument for StructureSpecificData
# xml.Reader got no structure=… argument for StructureSpecificData
# xml.Reader got no structure=… argument for StructureSpecificData
# xml.Reader got no structure=… argument for StructureSpecificData
# xml.Reader got no structure=… argument for StructureSpecificData
# xml.Reader got no structure=… argument for StructureSpecificData
# xml.Reader got no structure=… argument for StructureSpecificData
# xml.Reader got no structure=… argument for StructureSpecificData
# xml.Reader got no structure=… argument for StructureSpecificData
# xml.Reader got no structure=… argument for StructureSpecificData
# xml.Reader got no structure=… argument for StructureSpecificData
# xml.Reader got no structure=… argument for StructureSpecificData
# xml.Reader got no structure=… argument for StructureSpecificData
# xml.Reader got no structure=… argument for StructureSpecificData
# xml.Reader got no structure=… argument for StructureSpecificData
# xml.Reader got no structure=… argument for StructureSpecificData
# xml.Reader got no structure=… argument for StructureSpecificData
# xml.Reader got no structure=… argument for StructureSpecificData
# xml.Reader got no structure=… argument for StructureSpecificData
# xml.Reader got no structure=… argument for StructureSpecificData
# xml.Reader got no structure=… argument for StructureSpecificData
# xml.Reader got no structure=… argument for StructureSpecificData
# xml.Reader got no structure=… argument for StructureSpecificData
# xml.Reader got no structure=… argument for StructureSpecificData
# xml.Reader got no structure=… argument for StructureSpecificData
# xml.Reader got no structure=… argument for StructureSpecificData
# xml.Reader got no structure=… argument for StructureSpecificData
# xml.Reader got no structure=… argument for StructureSpecificData
# xml.Reader got no structure=… argument for StructureSpecificData
# xml.Reader got no structure=… argument for StructureSpecificData
# xml.Reader got no structure=… argument for StructureSpecificData
# xml.Reader got no structure=… argument for StructureSpecificData
# xml.Reader got no structure=… argument for StructureSpecificData
# xml.Reader got no structure=… argument for StructureSpecificData
# xml.Reader got no structure=… argument for StructureSpecificData
# xml.Reader got no structure=… argument for StructureSpecificData
# xml.Reader got no structure=… argument for StructureSpecificData
# xml.Reader got no structure=… argument for StructureSpecificData
# xml.Reader got no structure=… argument for StructureSpecificData
# xml.Reader got no structure=… argument for StructureSpecificData
# xml.Reader got no structure=… argument for StructureSpecificData
# xml.Reader got no structure=… argument for StructureSpecificData
# xml.Reader got no structure=… argument for StructureSpecificData
# xml.Reader got no structure=… argument for StructureSpecificData
# xml.Reader got no structure=… argument for StructureSpecificData
# xml.Reader got no structure=… argument for StructureSpecificData
# xml.Reader got no structure=… argument for StructureSpecificData
# xml.Reader got no structure=… argument for StructureSpecificData
# xml.Reader got no structure=… argument for StructureSpecificData
# xml.Reader got no structure=… argument for StructureSpecificData
# xml.Reader got no structure=… argument for StructureSpecificData
# xml.Reader got no structure=… argument for StructureSpecificData
# xml.Reader got no structure=… argument for StructureSpecificData
# xml.Reader got no structure=… argument for StructureSpecificData
# xml.Reader got no structure=… argument for StructureSpecificData
# xml.Reader got no structure=… argument for StructureSpecificData
# xml.Reader got no structure=… argument for StructureSpecificData

# %%
govt_debt
# Out:
# [71.069,
#  -99999.0,
#  8.255,
#  -99999.0,
#  -99999.0,
#  64.523,
#  54.295,
#  31.996,
#  -99999.0,
#  32.817,
#  73.091,
#  54.478,
#  -99999.0,
#  63.405,
#  50.937,
#  82.882,
#  21.017,
#  35.305,
#  -99999.0,
#  -99999.0,
#  106.418,
#  52.547,
#  50.163,
#  40.258,
#  28.04,
#  -99999.0,
#  141.423,
#  79.39,
#  33.794,
#  -99999.0,
#  42.922,
#  59.499,
#  -99999.0,
#  -99999.0,
#  92.405,
#  92.041,
#  97.733,
#  2.207,
#  -99999.0,
#  102.884,
#  42.953,
#  -99999.0,
#  58.292,
#  112.541,
#  -99999.0,
#  -99999.0,
#  -99999.0,
#  36.897,
#  -99999.0,
#  42.984,
#  96.306,
#  58.129,
#  -99999.0,
#  -99999.0,
#  39.866,
#  16.316,
#  91.401,
#  59.724,
#  32.513,
#  109.607,
#  59.661,
#  -99999.0,
#  -99999.0,
#  -99999.0,
#  -99999.0,
#  -99999.0,
#  60.282,
#  44.219,
#  -99999.0,
#  -99999.0,
#  65.381,
#  31.24,
#  -99999.0,
#  97.784,
#  -99999.0,
#  26.562,
#  -99999.0,
#  58.239,
#  -99999.0,
#  -99999.0,
#  -99999.0,
#  57.798,
#  -99999.0,
#  -99999.0,
#  -99999.0,
#  -99999.0,
#  -99999.0,
#  55.039,
#  86.589,
#  -99999.0,
#  -99999.0,
#  100.571,
#  25.405,
#  41.806,
#  -99999.0,
#  -99999.0,
#  86.441,
#  78.181,
#  116.301,
#  -99999.0,
#  9.176,
#  -99999.0,
#  79.236,
#  103.894,
#  35.849,
#  66.437,
#  -99999.0,
#  39.597,
#  67.475,
#  79.393,
#  35.074,
#  142.169,
#  71.394,
#  -99999.0,
#  27.232,
#  -99999.0,
#  27.695,
#  -99999.0,
#  11.806,
#  43.049,
#  -99999.0,
#  55.902,
#  11.773,
#  73.508,
#  -99999.0,
#  -99999.0,
#  -99999.0,
#  -99999.0,
#  -99999.0,
#  40.99,
#  -99999.0,
#  -99999.0,
#  80.391,
#  -99999.0,
#  36.681,
#  39.933,
#  50.216,
#  52.854,
#  69.083,
#  137.28,
#  64.601,
#  92.551,
#  234.858,
#  25.371,
#  68.344,
#  38.475,
#  29.077,
#  8.771,
#  60.203,
#  54.453,
#  7.354,
#  -99999.0,
#  91.38,
#  164.127,
#  56.498,
#  -99999.0,
#  73.634,
#  -99999.0,
#  -99999.0,
#  -99999.0,
#  -99999.0,
#  99.434,
#  -99999.0,
#  -99999.0,
#  59.729,
#  -99999.0,
#  41.837,
#  26.353,
#  48.322,
#  0.0,
#  -99999.0,
#  68.938,
#  -99999.0,
#  36.285,
#  -99999.0,
#  51.274,
#  140.795,
#  -99999.0,
#  60.664,
#  15.256,
#  -99999.0,
#  52.915,
#  51.731,
#  49.34,
#  62.6,
#  -99999.0,
#  60.325,
#  42.573,
#  -99999.0,
#  101.076,
#  45.72,
#  83.398,
#  72.957,
#  70.082,
#  -99999.0,
#  -99999.0,
#  63.863,
#  -99999.0,
#  43.394,
#  52.522,
#  38.423,
#  43.292,
#  42.72,
#  49.358,
#  -99999.0,
#  15.203,
#  -99999.0,
#  55.292,
#  -99999.0,
#  35.446,
#  -99999.0,
#  73.643,
#  58.105,
#  33.695,
#  58.142,
#  64.66,
#  51.994,
#  60.731,
#  -99999.0,
#  18.724,
#  -99999.0,
#  91.791,
#  43.906,
#  -99999.0,
#  -99999.0,
#  -99999.0,
#  -99999.0,
#  40.496,
#  61.64,
#  -99999.0,
#  21.383,
#  77.648,
#  -99999.0,
#  34.849,
#  251.981,
#  111.434,
#  174.94,
#  23.734,
#  44.334,
#  87.867,
#  64.138,
#  -99999.0,
#  44.388,
#  -99999.0,
#  63.173,
#  -99999.0,
#  -99999.0,
#  37.301,
#  86.588,
#  60.104,
#  67.987,
#  33.727,
#  37.815,
#  -99999.0,
#  -99999.0,
#  59.32,
#  -99999.0,
#  -99999.0,
#  33.884,
#  -99999.0,
#  -99999.0,
#  69.5,
#  64.513,
#  28.436,
#  4.504,
#  -99999.0,
#  13.852,
#  -99999.0,
#  44.128,
#  -99999.0,
#  -99999.0,
#  67.773,
#  82.872,
#  26.673,
#  3.257,
#  47.085,
#  53.956,
#  110.001,
#  -99999.0,
#  68.529,
#  122.464,
#  32.971,
#  93.546,
#  164.272,
#  -99999.0,
#  -99999.0,
#  33.566,
#  48.532,
#  -99999.0,
#  22.49,
#  -99999.0,
#  -99999.0,
#  71.24,
#  79.551,
#  114.943,
#  58.568]

# %%
dataset['govt_debt_as_%_of_gdp'] = govt_debt
dataset
# Out:
#       id iso2Code                                               name  \
# 0    ABW       AW                                              Aruba
# 1    AFE       ZH                        Africa Eastern and Southern
# 2    AFG       AF                                        Afghanistan
# 3    AFR       A9                                             Africa
# 4    AFW       ZI                         Africa Western and Central
# ..   ...      ...                                                ...
# 291  XZN       A5  Sub-Saharan Africa excluding South Africa and ...
# 292  YEM       YE                                        Yemen, Rep.
# 293  ZAF       ZA                                       South Africa
# 294  ZMB       ZM                                             Zambia
# 295  ZWE       ZW                                           Zimbabwe
#
#      inflation_rate  gdp_percent_change  unemployment_rate  \
# 0     -99999.000000               2.200                NaN
# 1     -99999.000000          -99999.000           7.772656
# 2         -3.366652               2.267          13.295000
# 3     -99999.000000          -99999.000                NaN
# 4     -99999.000000          -99999.000           3.218313
# ..              ...                 ...                ...
# 291   -99999.000000          -99999.000                NaN
# 292   -99999.000000              -1.500          17.086000
# 293        2.811107               0.979          33.168000
# 294       16.687222               6.200           5.961000
# 295      117.120451               6.022           8.554000
#
#      current_account_balance_%gdp  govt_debt_as_%_of_gdp
# 0                           9.701                 71.069
# 1                      -99999.000             -99999.000
# 2                         -20.306                  8.255
# 3                      -99999.000             -99999.000
# 4                      -99999.000             -99999.000
# ..                            ...                    ...
# 291                    -99999.000             -99999.000
# 292                       -12.082                 71.240
# 293                        -1.232                 79.551
# 294                         0.453                114.943
# 295                         2.994                 58.568
#
# [296 rows x 8 columns]

# %%
dataset.to_csv('dataset.csv', index=False)
